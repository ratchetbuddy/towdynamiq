# %%
import os
import pandas as pd
import json

# go up one level from current working dir (same pattern as your pricing script)
# BASE_DIR = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))
# DATA_DIR = os.path.join(BASE_DIR, "data")

# CSV_FILE = os.path.join(DATA_DIR, "cars.csv")
# JSON_FILE = os.path.join(DATA_DIR, "cars.json")

CSV_FILE = "cars.csv"
JSON_FILE = "cars.json"

print("Looking for CSV at:", CSV_FILE)

# If your cars.csv is tab-separated (which matches the file you pasted):
df = pd.read_csv(CSV_FILE)

# If instead it’s space-separated, use this line instead:
# df = pd.read_csv(CSV_FILE, delim_whitespace=True)


# Normalize headers
df.columns = df.columns.str.strip().str.lower()
print("Columns found:", df.columns.tolist())  # should show ['make','model','car_type','upcharge_percentage']

print("Columns found:", df.columns.tolist())  # debug

cars = {}

# Iterate rows safely
for _, row in df.iterrows():
    make = str(row["make"]).strip()
    model = str(row["model"]).strip()
    car_type = str(row["car_type"]).strip()
    upcharge = float(row["upcharge_percentage"])

    if make not in cars:
        cars[make] = {"label": make, "models": {}}

    cars[make]["models"][model] = {
        "label": model,
        "car_type": car_type,
        "upcharge_percentage": upcharge
    }

# Save JSON
with open(JSON_FILE, "w", encoding="utf-8") as f:
    json.dump(cars, f, indent=2, ensure_ascii=False)

print(f"✅ cars.json created successfully at {JSON_FILE}")

# Show first 2 makes as a sample
sample = {k: cars[k] for k in list(cars.keys())[:2]}
print(json.dumps(sample, indent=2, ensure_ascii=False))
# Out:
# Looking for CSV at: cars.csv
# Columns found: ['make', 'model', 'car_type', 'upcharge_percentage']
# Columns found: ['make', 'model', 'car_type', 'upcharge_percentage']
# ✅ cars.json created successfully at cars.json
# {
#   "Skoda": {
#     "label": "Skoda",
#     "models": {
#       "Octavia": {
#         "label": "Octavia",
#         "car_type": "Standard",
#         "upcharge_percentage": 0.0
#       }
#     }
#   },
#   "Acura": {
#     "label": "Acura",
#     "models": {
#       "MDX": {
#         "label": "MDX",
#         "car_type": "Standard",
#         "upcharge_percentage": 0.0
#       },
#       "RDX": {
#         "label": "RDX",
#         "car_type": "Standard",
#         "upcharge_percentage": 0.0
#       }
#     }
#   }
# }

# %%
import requests
import pandas as pd

def get_car_makes():
    """
    Fetch only car makes that produce passenger cars.
    Returns a list of dicts: [{'id': ..., 'name': ...}, ...]
    """
    url = "https://vpic.nhtsa.dot.gov/api/vehicles/GetMakesForVehicleType/car?format=json"
    res = requests.get(url)
    res.raise_for_status()
    data = res.json()
    return [{"id": m["MakeId"], "name": m["MakeName"]} for m in data["Results"]]

def get_models_for_make_id(make_id: int):
    """
    Fetch models for a specific make using Make_ID.
    Returns a list of model names.
    """
    url = f"https://vpic.nhtsa.dot.gov/api/vehicles/GetModelsForMakeId/{make_id}?format=json"
    res = requests.get(url)
    res.raise_for_status()
    data = res.json()
    return [m["Model_Name"] for m in data["Results"]]

# Build flat list of make+model
all_rows = []
makes = get_car_makes()

for make in makes:
    try:
        models = get_models_for_make_id(make["id"])
        for model in models:
            all_rows.append({
                "make": make["name"].strip(),
                "model": model.strip()
            })
    except Exception as e:
        print(f"Skipping {make['name']} (ID {make['id']}): {e}")

# Create DataFrame and drop duplicates
df = pd.DataFrame(all_rows).drop_duplicates().reset_index(drop=True)

df = df.drop_duplicates().reset_index(drop=True)

df.to_csv("car_makes_models_from_api.csv", index=False)
print("✅ Saved car_makes_models_from_api.csv with", len(df), "rows")
# Preview first 20 rows
# df.head(20)
# Out:
# ✅ Saved car_makes_models_from_api.csv with 3130 rows

# %%
import requests
import pandas as pd
import time

def get_car_makes():
    """
    Fetch only car makes that produce passenger cars.
    Returns a list of dicts: [{'id': ..., 'name': ...}, ...]
    """
    start = time.time()
    url = "https://vpic.nhtsa.dot.gov/api/vehicles/GetMakesForVehicleType/car?format=json"
    res = requests.get(url)
    res.raise_for_status()
    data = res.json()
    makes = [{"id": m["MakeId"], "name": m["MakeName"]} for m in data["Results"]]
    end = time.time()
    print(f"⏱ get_car_makes() took {end - start:.2f} seconds")
    return makes

def get_models_for_make_id(make_id: int):
    """
    Fetch models for a specific make using Make_ID.
    Returns a list of model names.
    """
    start = time.time()
    url = f"https://vpic.nhtsa.dot.gov/api/vehicles/GetModelsForMakeId/{make_id}?format=json"
    res = requests.get(url)
    res.raise_for_status()
    data = res.json()
    models = [m["Model_Name"] for m in data["Results"]]
    end = time.time()
    print(f"   ↳ get_models_for_make_id({make_id}) took {end - start:.2f} seconds, got {len(models)} models")
    return models

# Measure whole process
overall_start = time.time()

# Build flat list of make+model
all_rows = []
makes = get_car_makes()

for make in makes:
    try:
        models = get_models_for_make_id(make["id"])
        for model in models:
            all_rows.append({
                "make": make["name"].strip(),
                "model": model.strip()
            })
    except Exception as e:
        print(f"Skipping {make['name']} (ID {make['id']}): {e}")

# Create DataFrame and drop duplicates
df = pd.DataFrame(all_rows).drop_duplicates().reset_index(drop=True)

df.to_csv("car_makes_models_from_api.csv", index=False)

overall_end = time.time()

print("✅ Saved car_makes_models_from_api.csv with", len(df), "rows")
print(f"⏱ Total process time: {overall_end - overall_start:.2f} seconds")
# Out:
# ⏱ get_car_makes() took 0.46 seconds
#    ↳ get_models_for_make_id(440) took 0.17 seconds, got 18 models
#    ↳ get_models_for_make_id(441) took 0.18 seconds, got 7 models
#    ↳ get_models_for_make_id(442) took 0.19 seconds, got 17 models
#    ↳ get_models_for_make_id(443) took 0.18 seconds, got 14 models
#    ↳ get_models_for_make_id(445) took 0.19 seconds, got 15 models
#    ↳ get_models_for_make_id(448) took 0.21 seconds, got 56 models
#    ↳ get_models_for_make_id(449) took 0.19 seconds, got 60 models
#    ↳ get_models_for_make_id(452) took 0.19 seconds, got 258 models
#    ↳ get_models_for_make_id(454) took 0.20 seconds, got 6 models
#    ↳ get_models_for_make_id(456) took 0.20 seconds, got 8 models
#    ↳ get_models_for_make_id(460) took 0.24 seconds, got 149 models
#    ↳ get_models_for_make_id(464) took 0.17 seconds, got 17 models
#    ↳ get_models_for_make_id(465) took 0.17 seconds, got 17 models
#    ↳ get_models_for_make_id(466) took 0.21 seconds, got 19 models
#    ↳ get_models_for_make_id(467) took 0.18 seconds, got 124 models
#    ↳ get_models_for_make_id(468) took 0.17 seconds, got 27 models
#    ↳ get_models_for_make_id(469) took 0.21 seconds, got 37 models
#    ↳ get_models_for_make_id(470) took 0.17 seconds, got 3 models
#    ↳ get_models_for_make_id(471) took 0.19 seconds, got 6 models
#    ↳ get_models_for_make_id(472) took 0.18 seconds, got 61 models
#    ↳ get_models_for_make_id(473) took 0.16 seconds, got 28 models
#    ↳ get_models_for_make_id(474) took 0.18 seconds, got 541 models
#    ↳ get_models_for_make_id(475) took 0.19 seconds, got 17 models
#    ↳ get_models_for_make_id(476) took 0.18 seconds, got 51 models
#    ↳ get_models_for_make_id(477) took 0.18 seconds, got 38 models
#    ↳ get_models_for_make_id(478) took 0.18 seconds, got 44 models
#    ↳ get_models_for_make_id(480) took 0.17 seconds, got 33 models
#    ↳ get_models_for_make_id(481) took 0.18 seconds, got 32 models
#    ↳ get_models_for_make_id(482) took 0.20 seconds, got 40 models
#    ↳ get_models_for_make_id(485) took 0.21 seconds, got 64 models
#    ↳ get_models_for_make_id(492) took 0.19 seconds, got 11 models
#    ↳ get_models_for_make_id(493) took 0.18 seconds, got 9 models
#    ↳ get_models_for_make_id(497) took 0.18 seconds, got 3 models
#    ↳ get_models_for_make_id(498) took 0.18 seconds, got 37 models
#    ↳ get_models_for_make_id(499) took 0.19 seconds, got 24 models
#    ↳ get_models_for_make_id(502) took 0.20 seconds, got 9 models
#    ↳ get_models_for_make_id(504) took 0.19 seconds, got 4 models
#    ↳ get_models_for_make_id(509) took 0.21 seconds, got 393 models
#    ↳ get_models_for_make_id(515) took 0.22 seconds, got 17 models
#    ↳ get_models_for_make_id(523) took 0.19 seconds, got 24 models
#    ↳ get_models_for_make_id(533) took 0.21 seconds, got 2 models
#    ↳ get_models_for_make_id(536) took 0.18 seconds, got 37 models
#    ↳ get_models_for_make_id(542) took 0.23 seconds, got 46 models
#    ↳ get_models_for_make_id(565) took 0.19 seconds, got 34 models
#    ↳ get_models_for_make_id(572) took 0.20 seconds, got 7 models
#    ↳ get_models_for_make_id(582) took 0.18 seconds, got 55 models
#    ↳ get_models_for_make_id(583) took 0.16 seconds, got 12 models
#    ↳ get_models_for_make_id(584) took 0.16 seconds, got 15 models
#    ↳ get_models_for_make_id(603) took 0.18 seconds, got 83 models
#    ↳ get_models_for_make_id(606) took 0.17 seconds, got 1 models
#    ↳ get_models_for_make_id(629) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id(771) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id(847) took 0.17 seconds, got 3 models
#    ↳ get_models_for_make_id(972) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id(986) took 0.20 seconds, got 9 models
#    ↳ get_models_for_make_id(992) took 0.23 seconds, got 1 models
#    ↳ get_models_for_make_id(1056) took 0.21 seconds, got 24 models
#    ↳ get_models_for_make_id(1077) took 0.23 seconds, got 6 models
#    ↳ get_models_for_make_id(1124) took 0.29 seconds, got 4 models
#    ↳ get_models_for_make_id(1142) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id(1146) took 0.18 seconds, got 6 models
#    ↳ get_models_for_make_id(1151) took 0.22 seconds, got 5 models
#    ↳ get_models_for_make_id(1288) took 0.16 seconds, got 6 models
#    ↳ get_models_for_make_id(1292) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(1393) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id(1498) took 0.18 seconds, got 4 models
#    ↳ get_models_for_make_id(1683) took 0.21 seconds, got 1 models
#    ↳ get_models_for_make_id(1755) took 0.21 seconds, got 2 models
#    ↳ get_models_for_make_id(1777) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(1869) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(1896) took 0.17 seconds, got 6 models
#    ↳ get_models_for_make_id(1991) took 0.32 seconds, got 32 models
#    ↳ get_models_for_make_id(2018) took 0.18 seconds, got 17 models
#    ↳ get_models_for_make_id(2049) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(2131) took 0.17 seconds, got 1 models
#    ↳ get_models_for_make_id(2236) took 0.27 seconds, got 19 models
#    ↳ get_models_for_make_id(2376) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(2408) took 0.18 seconds, got 7 models
#    ↳ get_models_for_make_id(2409) took 0.17 seconds, got 20 models
#    ↳ get_models_for_make_id(2665) took 0.20 seconds, got 1 models
#    ↳ get_models_for_make_id(2745) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(3176) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id(3440) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(3540) took 0.27 seconds, got 2 models
#    ↳ get_models_for_make_id(3583) took 0.31 seconds, got 17 models
#    ↳ get_models_for_make_id(3706) took 0.23 seconds, got 2 models
#    ↳ get_models_for_make_id(3766) took 0.23 seconds, got 3 models
#    ↳ get_models_for_make_id(4162) took 0.17 seconds, got 21 models
#    ↳ get_models_for_make_id(4220) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(4355) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(4410) took 0.17 seconds, got 4 models
#    ↳ get_models_for_make_id(4451) took 0.19 seconds, got 8 models
#    ↳ get_models_for_make_id(4596) took 0.22 seconds, got 1 models
#    ↳ get_models_for_make_id(4634) took 0.17 seconds, got 6 models
#    ↳ get_models_for_make_id(4644) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(4764) took 0.17 seconds, got 2 models
#    ↳ get_models_for_make_id(4767) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id(4859) took 0.23 seconds, got 1 models
#    ↳ get_models_for_make_id(5015) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id(5042) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id(5083) took 0.21 seconds, got 6 models
#    ↳ get_models_for_make_id(5122) took 0.17 seconds, got 7 models
#    ↳ get_models_for_make_id(5208) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(5367) took 0.17 seconds, got 16 models
#    ↳ get_models_for_make_id(5381) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(5464) took 0.26 seconds, got 1 models
#    ↳ get_models_for_make_id(5468) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id(5552) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id(5553) took 0.19 seconds, got 4 models
#    ↳ get_models_for_make_id(5554) took 0.18 seconds, got 4 models
#    ↳ get_models_for_make_id(5555) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id(5557) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id(5657) took 0.17 seconds, got 4 models
#    ↳ get_models_for_make_id(5661) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(5760) took 0.27 seconds, got 2 models
#    ↳ get_models_for_make_id(5767) took 0.40 seconds, got 1 models
#    ↳ get_models_for_make_id(5848) took 0.36 seconds, got 1 models
#    ↳ get_models_for_make_id(5938) took 0.39 seconds, got 1 models
#    ↳ get_models_for_make_id(6018) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(6069) took 0.30 seconds, got 3 models
#    ↳ get_models_for_make_id(6263) took 0.36 seconds, got 2 models
#    ↳ get_models_for_make_id(6264) took 0.45 seconds, got 1 models
#    ↳ get_models_for_make_id(6265) took 0.38 seconds, got 2 models
#    ↳ get_models_for_make_id(6313) took 0.44 seconds, got 1 models
#    ↳ get_models_for_make_id(6364) took 0.35 seconds, got 1 models
#    ↳ get_models_for_make_id(6408) took 0.39 seconds, got 1 models
#    ↳ get_models_for_make_id(6473) took 0.38 seconds, got 3 models
#    ↳ get_models_for_make_id(6663) took 0.20 seconds, got 2 models
#    ↳ get_models_for_make_id(6759) took 0.50 seconds, got 1 models
#    ↳ get_models_for_make_id(6792) took 0.19 seconds, got 3 models
#    ↳ get_models_for_make_id(6880) took 0.17 seconds, got 7 models
#    ↳ get_models_for_make_id(6986) took 0.19 seconds, got 4 models
#    ↳ get_models_for_make_id(7099) took 0.17 seconds, got 2 models
#    ↳ get_models_for_make_id(7207) took 0.17 seconds, got 2 models
#    ↳ get_models_for_make_id(7225) took 0.21 seconds, got 5 models
#    ↳ get_models_for_make_id(7425) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(7477) took 0.20 seconds, got 5 models
#    ↳ get_models_for_make_id(7765) took 0.17 seconds, got 5 models
#    ↳ get_models_for_make_id(7836) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(8395) took 0.17 seconds, got 1 models
#    ↳ get_models_for_make_id(8549) took 0.17 seconds, got 2 models
#    ↳ get_models_for_make_id(8605) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id(8785) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id(9250) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(9326) took 0.17 seconds, got 1 models
#    ↳ get_models_for_make_id(9364) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(9376) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(9401) took 0.18 seconds, got 3 models
#    ↳ get_models_for_make_id(9448) took 0.17 seconds, got 1 models
#    ↳ get_models_for_make_id(9458) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(9533) took 0.21 seconds, got 1 models
#    ↳ get_models_for_make_id(9572) took 0.18 seconds, got 3 models
#    ↳ get_models_for_make_id(9720) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(9759) took 0.17 seconds, got 16 models
#    ↳ get_models_for_make_id(10029) took 0.17 seconds, got 6 models
#    ↳ get_models_for_make_id(10030) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id(10031) took 0.17 seconds, got 2 models
#    ↳ get_models_for_make_id(10047) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(10224) took 0.16 seconds, got 4 models
#    ↳ get_models_for_make_id(10256) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(10393) took 0.18 seconds, got 6 models
#    ↳ get_models_for_make_id(10623) took 0.18 seconds, got 3 models
#    ↳ get_models_for_make_id(10647) took 0.20 seconds, got 1 models
#    ↳ get_models_for_make_id(10919) took 0.23 seconds, got 2 models
#    ↳ get_models_for_make_id(11076) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(11346) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(11792) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(11832) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id(11856) took 0.19 seconds, got 3 models
#    ↳ get_models_for_make_id(11921) took 0.15 seconds, got 1 models
#    ↳ get_models_for_make_id(11938) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id(12074) took 0.16 seconds, got 2 models
#    ↳ get_models_for_make_id(12400) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(12550) took 0.16 seconds, got 4 models
#    ↳ get_models_for_make_id(12706) took 0.20 seconds, got 1 models
#    ↳ get_models_for_make_id(12771) took 0.18 seconds, got 3 models
#    ↳ get_models_for_make_id(12783) took 0.17 seconds, got 2 models
#    ↳ get_models_for_make_id(12894) took 0.17 seconds, got 3 models
#    ↳ get_models_for_make_id(12948) took 0.17 seconds, got 1 models
#    ↳ get_models_for_make_id(12980) took 0.22 seconds, got 1 models
#    ↳ get_models_for_make_id(12991) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id(13018) took 0.17 seconds, got 2 models
#    ↳ get_models_for_make_id(13022) took 0.16 seconds, got 1 models
#    ↳ get_models_for_make_id(13024) took 0.21 seconds, got 1 models
#    ↳ get_models_for_make_id(13025) took 0.20 seconds, got 2 models
#    ↳ get_models_for_make_id(13026) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id(13028) took 0.21 seconds, got 1 models
#    ↳ get_models_for_make_id(13271) took 0.17 seconds, got 1 models
#    ↳ get_models_for_make_id(13380) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(13391) took 0.20 seconds, got 4 models
#    ↳ get_models_for_make_id(13585) took 0.17 seconds, got 13 models
#    ↳ get_models_for_make_id(13647) took 0.21 seconds, got 5 models
# ✅ Saved car_makes_models_from_api.csv with 3130 rows
# ⏱ Total process time: 39.60 seconds

# %%
import requests
import pandas as pd
import time

def get_car_makes():
    """
    Fetch only car makes that produce passenger cars in the US.
    Returns a list of dicts: [{'id': ..., 'name': ...}, ...]
    """
    start = time.time()
    url = "https://vpic.nhtsa.dot.gov/api/vehicles/GetMakesForVehicleType/car?format=json"
    res = requests.get(url)
    res.raise_for_status()
    data = res.json()
    makes = [{"id": m["MakeId"], "name": m["MakeName"]} for m in data["Results"]]
    end = time.time()
    print(f"⏱ get_car_makes() took {end - start:.2f} seconds")
    return makes

def get_models_for_make_id_year(make_id: int, year: int):
    """
    Fetch car models for a specific make_id and year.
    Only returns US passenger cars certified/sold in that year.
    """
    start = time.time()
    url = f"https://vpic.nhtsa.dot.gov/api/vehicles/GetModelsForMakeIdYear/makeId/{make_id}/modelyear/{year}/vehicleType/car?format=json"
    res = requests.get(url)
    res.raise_for_status()
    data = res.json()
    models = [m["Model_Name"] for m in data["Results"]]
    end = time.time()
    print(f"   ↳ get_models_for_make_id_year({make_id}, {year}) took {end - start:.2f} seconds, got {len(models)} models")
    return models

# Measure whole process
overall_start = time.time()

# Choose year(s) you care about (e.g., last 5 years to cover current sales)
years = range(1996, 2026)

all_rows = []
makes = get_car_makes()

for make in makes:
    try:
        for year in years:
            models = get_models_for_make_id_year(make["id"], year)
            for model in models:
                all_rows.append({
                    "make": make["name"].strip(),
                    "model": model.strip(),
                    "year": year
                })
    except Exception as e:
        print(f"Skipping {make['name']} (ID {make['id']}): {e}")

# Create DataFrame and drop duplicates
df = pd.DataFrame(all_rows).drop_duplicates().reset_index(drop=True)

df.to_csv("car_makes_models_us.csv", index=False)

overall_end = time.time()

print("✅ Saved car_makes_models_us.csv with", len(df), "rows")
print(f"⏱ Total process time: {overall_end - overall_start:.2f} seconds")
# Out:
# ⏱ get_car_makes() took 0.54 seconds
#    ↳ get_models_for_make_id_year(440, 1996) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id_year(440, 1997) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id_year(440, 1998) took 0.36 seconds, got 1 models
#    ↳ get_models_for_make_id_year(440, 1999) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id_year(440, 2000) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id_year(440, 2001) took 0.22 seconds, got 2 models
#    ↳ get_models_for_make_id_year(440, 2002) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id_year(440, 2003) took 0.22 seconds, got 2 models
#    ↳ get_models_for_make_id_year(440, 2004) took 0.24 seconds, got 1 models
#    ↳ get_models_for_make_id_year(440, 2005) took 0.20 seconds, got 2 models
#    ↳ get_models_for_make_id_year(440, 2006) took 0.17 seconds, got 3 models
#    ↳ get_models_for_make_id_year(440, 2007) took 0.16 seconds, got 3 models
#    ↳ get_models_for_make_id_year(440, 2008) took 0.21 seconds, got 2 models
#    ↳ get_models_for_make_id_year(440, 2009) took 0.18 seconds, got 3 models
#    ↳ get_models_for_make_id_year(440, 2010) took 0.18 seconds, got 4 models
#    ↳ get_models_for_make_id_year(440, 2011) took 0.23 seconds, got 5 models
#    ↳ get_models_for_make_id_year(440, 2012) took 0.23 seconds, got 6 models
#    ↳ get_models_for_make_id_year(440, 2013) took 0.17 seconds, got 3 models
#    ↳ get_models_for_make_id_year(440, 2014) took 0.18 seconds, got 4 models
#    ↳ get_models_for_make_id_year(440, 2015) took 0.19 seconds, got 5 models
#    ↳ get_models_for_make_id_year(440, 2016) took 0.20 seconds, got 5 models
#    ↳ get_models_for_make_id_year(440, 2017) took 0.18 seconds, got 5 models
#    ↳ get_models_for_make_id_year(440, 2018) took 0.20 seconds, got 6 models
#    ↳ get_models_for_make_id_year(440, 2019) took 0.19 seconds, got 5 models
#    ↳ get_models_for_make_id_year(440, 2020) took 0.19 seconds, got 3 models
#    ↳ get_models_for_make_id_year(440, 2021) took 0.18 seconds, got 4 models
#    ↳ get_models_for_make_id_year(440, 2022) took 0.19 seconds, got 3 models
#    ↳ get_models_for_make_id_year(440, 2023) took 0.19 seconds, got 3 models
#    ↳ get_models_for_make_id_year(440, 2024) took 0.17 seconds, got 6 models
#    ↳ get_models_for_make_id_year(440, 2025) took 0.20 seconds, got 5 models
#    ↳ get_models_for_make_id_year(441, 1996) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(441, 1997) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(441, 1998) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(441, 1999) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(441, 2000) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(441, 2001) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(441, 2002) took 0.22 seconds, got 0 models
#    ↳ get_models_for_make_id_year(441, 2003) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(441, 2004) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(441, 2005) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(441, 2006) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(441, 2007) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(441, 2008) took 0.17 seconds, got 1 models
#    ↳ get_models_for_make_id_year(441, 2009) took 0.21 seconds, got 1 models
#    ↳ get_models_for_make_id_year(441, 2010) took 0.25 seconds, got 1 models
#    ↳ get_models_for_make_id_year(441, 2011) took 0.20 seconds, got 1 models
#    ↳ get_models_for_make_id_year(441, 2012) took 0.17 seconds, got 2 models
#    ↳ get_models_for_make_id_year(441, 2013) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id_year(441, 2014) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id_year(441, 2015) took 0.26 seconds, got 1 models
#    ↳ get_models_for_make_id_year(441, 2016) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id_year(441, 2017) took 0.17 seconds, got 3 models
#    ↳ get_models_for_make_id_year(441, 2018) took 0.19 seconds, got 3 models
#    ↳ get_models_for_make_id_year(441, 2019) took 0.20 seconds, got 3 models
#    ↳ get_models_for_make_id_year(441, 2020) took 0.18 seconds, got 4 models
#    ↳ get_models_for_make_id_year(441, 2021) took 0.19 seconds, got 4 models
#    ↳ get_models_for_make_id_year(441, 2022) took 0.20 seconds, got 2 models
#    ↳ get_models_for_make_id_year(441, 2023) took 0.30 seconds, got 2 models
#    ↳ get_models_for_make_id_year(441, 2024) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id_year(441, 2025) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id_year(442, 1996) took 0.34 seconds, got 5 models
#    ↳ get_models_for_make_id_year(442, 1997) took 0.19 seconds, got 6 models
#    ↳ get_models_for_make_id_year(442, 1998) took 0.27 seconds, got 4 models
#    ↳ get_models_for_make_id_year(442, 1999) took 0.18 seconds, got 4 models
#    ↳ get_models_for_make_id_year(442, 2000) took 0.20 seconds, got 6 models
#    ↳ get_models_for_make_id_year(442, 2001) took 0.17 seconds, got 6 models
#    ↳ get_models_for_make_id_year(442, 2002) took 0.18 seconds, got 8 models
#    ↳ get_models_for_make_id_year(442, 2003) took 0.17 seconds, got 8 models
#    ↳ get_models_for_make_id_year(442, 2004) took 0.19 seconds, got 7 models
#    ↳ get_models_for_make_id_year(442, 2005) took 0.19 seconds, got 5 models
#    ↳ get_models_for_make_id_year(442, 2006) took 0.18 seconds, got 5 models
#    ↳ get_models_for_make_id_year(442, 2007) took 0.20 seconds, got 5 models
#    ↳ get_models_for_make_id_year(442, 2008) took 0.22 seconds, got 4 models
#    ↳ get_models_for_make_id_year(442, 2009) took 0.31 seconds, got 3 models
#    ↳ get_models_for_make_id_year(442, 2010) took 0.19 seconds, got 3 models
#    ↳ get_models_for_make_id_year(442, 2011) took 0.21 seconds, got 3 models
#    ↳ get_models_for_make_id_year(442, 2012) took 0.31 seconds, got 3 models
#    ↳ get_models_for_make_id_year(442, 2013) took 0.21 seconds, got 3 models
#    ↳ get_models_for_make_id_year(442, 2014) took 0.19 seconds, got 4 models
#    ↳ get_models_for_make_id_year(442, 2015) took 0.18 seconds, got 4 models
#    ↳ get_models_for_make_id_year(442, 2016) took 0.22 seconds, got 3 models
#    ↳ get_models_for_make_id_year(442, 2017) took 0.18 seconds, got 4 models
#    ↳ get_models_for_make_id_year(442, 2018) took 0.24 seconds, got 4 models
#    ↳ get_models_for_make_id_year(442, 2019) took 0.19 seconds, got 4 models
#    ↳ get_models_for_make_id_year(442, 2020) took 0.25 seconds, got 3 models
#    ↳ get_models_for_make_id_year(442, 2021) took 0.21 seconds, got 3 models
#    ↳ get_models_for_make_id_year(442, 2022) took 0.17 seconds, got 2 models
#    ↳ get_models_for_make_id_year(442, 2023) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id_year(442, 2024) took 0.20 seconds, got 2 models
#    ↳ get_models_for_make_id_year(442, 2025) took 0.17 seconds, got 2 models
#    ↳ get_models_for_make_id_year(443, 1996) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(443, 1997) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(443, 1998) took 0.30 seconds, got 0 models
#    ↳ get_models_for_make_id_year(443, 1999) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(443, 2000) took 0.20 seconds, got 0 models
#    ↳ get_models_for_make_id_year(443, 2001) took 0.20 seconds, got 0 models
#    ↳ get_models_for_make_id_year(443, 2002) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id_year(443, 2003) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id_year(443, 2004) took 0.21 seconds, got 2 models
#    ↳ get_models_for_make_id_year(443, 2005) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id_year(443, 2006) took 0.52 seconds, got 3 models
#    ↳ get_models_for_make_id_year(443, 2007) took 0.17 seconds, got 1 models
#    ↳ get_models_for_make_id_year(443, 2008) took 0.20 seconds, got 2 models
#    ↳ get_models_for_make_id_year(443, 2009) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id_year(443, 2010) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id_year(443, 2011) took 0.20 seconds, got 2 models
#    ↳ get_models_for_make_id_year(443, 2012) took 0.20 seconds, got 2 models
#    ↳ get_models_for_make_id_year(443, 2013) took 0.17 seconds, got 2 models
#    ↳ get_models_for_make_id_year(443, 2014) took 0.18 seconds, got 3 models
#    ↳ get_models_for_make_id_year(443, 2015) took 0.21 seconds, got 3 models
#    ↳ get_models_for_make_id_year(443, 2016) took 0.17 seconds, got 3 models
#    ↳ get_models_for_make_id_year(443, 2017) took 0.21 seconds, got 3 models
#    ↳ get_models_for_make_id_year(443, 2018) took 0.18 seconds, got 3 models
#    ↳ get_models_for_make_id_year(443, 2019) took 0.21 seconds, got 3 models
#    ↳ get_models_for_make_id_year(443, 2020) took 0.19 seconds, got 3 models
#    ↳ get_models_for_make_id_year(443, 2021) took 0.32 seconds, got 3 models
#    ↳ get_models_for_make_id_year(443, 2022) took 0.20 seconds, got 4 models
#    ↳ get_models_for_make_id_year(443, 2023) took 0.19 seconds, got 4 models
#    ↳ get_models_for_make_id_year(443, 2024) took 0.25 seconds, got 5 models
#    ↳ get_models_for_make_id_year(443, 2025) took 0.20 seconds, got 5 models
#    ↳ get_models_for_make_id_year(445, 1996) took 0.23 seconds, got 4 models
#    ↳ get_models_for_make_id_year(445, 1997) took 0.20 seconds, got 3 models
#    ↳ get_models_for_make_id_year(445, 1998) took 0.19 seconds, got 3 models
#    ↳ get_models_for_make_id_year(445, 1999) took 0.19 seconds, got 3 models
#    ↳ get_models_for_make_id_year(445, 2000) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id_year(445, 2001) took 0.32 seconds, got 3 models
#    ↳ get_models_for_make_id_year(445, 2002) took 0.18 seconds, got 3 models
#    ↳ get_models_for_make_id_year(445, 2003) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(445, 2004) took 0.17 seconds, got 1 models
#    ↳ get_models_for_make_id_year(445, 2005) took 0.23 seconds, got 1 models
#    ↳ get_models_for_make_id_year(445, 2006) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id_year(445, 2007) took 0.26 seconds, got 1 models
#    ↳ get_models_for_make_id_year(445, 2008) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id_year(445, 2009) took 0.22 seconds, got 1 models
#    ↳ get_models_for_make_id_year(445, 2010) took 0.31 seconds, got 2 models
#    ↳ get_models_for_make_id_year(445, 2011) took 0.26 seconds, got 2 models
#    ↳ get_models_for_make_id_year(445, 2012) took 0.25 seconds, got 2 models
#    ↳ get_models_for_make_id_year(445, 2013) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id_year(445, 2014) took 0.17 seconds, got 3 models
#    ↳ get_models_for_make_id_year(445, 2015) took 0.18 seconds, got 3 models
#    ↳ get_models_for_make_id_year(445, 2016) took 0.18 seconds, got 4 models
#    ↳ get_models_for_make_id_year(445, 2017) took 0.29 seconds, got 4 models
#    ↳ get_models_for_make_id_year(445, 2018) took 0.25 seconds, got 4 models
#    ↳ get_models_for_make_id_year(445, 2019) took 0.21 seconds, got 4 models
#    ↳ get_models_for_make_id_year(445, 2020) took 0.17 seconds, got 4 models
#    ↳ get_models_for_make_id_year(445, 2021) took 0.22 seconds, got 4 models
#    ↳ get_models_for_make_id_year(445, 2022) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id_year(445, 2023) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id_year(445, 2024) took 0.21 seconds, got 3 models
#    ↳ get_models_for_make_id_year(445, 2025) took 0.31 seconds, got 3 models
#    ↳ get_models_for_make_id_year(448, 1996) took 0.17 seconds, got 7 models
#    ↳ get_models_for_make_id_year(448, 1997) took 0.33 seconds, got 7 models
#    ↳ get_models_for_make_id_year(448, 1998) took 0.21 seconds, got 7 models
#    ↳ get_models_for_make_id_year(448, 1999) took 0.20 seconds, got 7 models
#    ↳ get_models_for_make_id_year(448, 2000) took 0.22 seconds, got 8 models
#    ↳ get_models_for_make_id_year(448, 2001) took 0.20 seconds, got 9 models
#    ↳ get_models_for_make_id_year(448, 2002) took 0.19 seconds, got 9 models
#    ↳ get_models_for_make_id_year(448, 2003) took 0.19 seconds, got 10 models
#    ↳ get_models_for_make_id_year(448, 2004) took 0.21 seconds, got 11 models
#    ↳ get_models_for_make_id_year(448, 2005) took 0.24 seconds, got 12 models
#    ↳ get_models_for_make_id_year(448, 2006) took 0.20 seconds, got 11 models
#    ↳ get_models_for_make_id_year(448, 2007) took 0.31 seconds, got 11 models
#    ↳ get_models_for_make_id_year(448, 2008) took 0.30 seconds, got 11 models
#    ↳ get_models_for_make_id_year(448, 2009) took 0.31 seconds, got 12 models
#    ↳ get_models_for_make_id_year(448, 2010) took 0.18 seconds, got 11 models
#    ↳ get_models_for_make_id_year(448, 2011) took 0.19 seconds, got 12 models
#    ↳ get_models_for_make_id_year(448, 2012) took 0.23 seconds, got 14 models
#    ↳ get_models_for_make_id_year(448, 2013) took 0.42 seconds, got 15 models
#    ↳ get_models_for_make_id_year(448, 2014) took 0.18 seconds, got 14 models
#    ↳ get_models_for_make_id_year(448, 2015) took 0.18 seconds, got 13 models
#    ↳ get_models_for_make_id_year(448, 2016) took 0.20 seconds, got 15 models
#    ↳ get_models_for_make_id_year(448, 2017) took 0.18 seconds, got 15 models
#    ↳ get_models_for_make_id_year(448, 2018) took 0.18 seconds, got 15 models
#    ↳ get_models_for_make_id_year(448, 2019) took 0.16 seconds, got 14 models
#    ↳ get_models_for_make_id_year(448, 2020) took 0.20 seconds, got 14 models
#    ↳ get_models_for_make_id_year(448, 2021) took 0.19 seconds, got 12 models
#    ↳ get_models_for_make_id_year(448, 2022) took 0.21 seconds, got 13 models
#    ↳ get_models_for_make_id_year(448, 2023) took 0.18 seconds, got 14 models
#    ↳ get_models_for_make_id_year(448, 2024) took 0.19 seconds, got 14 models
#    ↳ get_models_for_make_id_year(448, 2025) took 0.29 seconds, got 15 models
#    ↳ get_models_for_make_id_year(449, 1996) took 0.18 seconds, got 4 models
#    ↳ get_models_for_make_id_year(449, 1997) took 0.20 seconds, got 4 models
#    ↳ get_models_for_make_id_year(449, 1998) took 0.19 seconds, got 7 models
#    ↳ get_models_for_make_id_year(449, 1999) took 0.19 seconds, got 8 models
#    ↳ get_models_for_make_id_year(449, 2000) took 0.19 seconds, got 7 models
#    ↳ get_models_for_make_id_year(449, 2001) took 0.17 seconds, got 7 models
#    ↳ get_models_for_make_id_year(449, 2002) took 0.19 seconds, got 7 models
#    ↳ get_models_for_make_id_year(449, 2003) took 0.19 seconds, got 7 models
#    ↳ get_models_for_make_id_year(449, 2004) took 0.22 seconds, got 8 models
#    ↳ get_models_for_make_id_year(449, 2005) took 0.19 seconds, got 9 models
#    ↳ get_models_for_make_id_year(449, 2006) took 0.33 seconds, got 9 models
#    ↳ get_models_for_make_id_year(449, 2007) took 0.18 seconds, got 9 models
#    ↳ get_models_for_make_id_year(449, 2008) took 0.42 seconds, got 9 models
#    ↳ get_models_for_make_id_year(449, 2009) took 0.53 seconds, got 9 models
#    ↳ get_models_for_make_id_year(449, 2010) took 0.30 seconds, got 6 models
#    ↳ get_models_for_make_id_year(449, 2011) took 0.23 seconds, got 9 models
#    ↳ get_models_for_make_id_year(449, 2012) took 0.19 seconds, got 9 models
#    ↳ get_models_for_make_id_year(449, 2013) took 0.19 seconds, got 8 models
#    ↳ get_models_for_make_id_year(449, 2014) took 0.19 seconds, got 10 models
#    ↳ get_models_for_make_id_year(449, 2015) took 0.23 seconds, got 10 models
#    ↳ get_models_for_make_id_year(449, 2016) took 0.31 seconds, got 11 models
#    ↳ get_models_for_make_id_year(449, 2017) took 0.19 seconds, got 11 models
#    ↳ get_models_for_make_id_year(449, 2018) took 0.22 seconds, got 11 models
#    ↳ get_models_for_make_id_year(449, 2019) took 0.21 seconds, got 12 models
#    ↳ get_models_for_make_id_year(449, 2020) took 0.20 seconds, got 12 models
#    ↳ get_models_for_make_id_year(449, 2021) took 0.19 seconds, got 10 models
#    ↳ get_models_for_make_id_year(449, 2022) took 0.23 seconds, got 11 models
#    ↳ get_models_for_make_id_year(449, 2023) took 0.19 seconds, got 9 models
#    ↳ get_models_for_make_id_year(449, 2024) took 0.29 seconds, got 9 models
#    ↳ get_models_for_make_id_year(449, 2025) took 0.20 seconds, got 9 models
#    ↳ get_models_for_make_id_year(452, 1996) took 0.18 seconds, got 13 models
#    ↳ get_models_for_make_id_year(452, 1997) took 0.19 seconds, got 11 models
#    ↳ get_models_for_make_id_year(452, 1998) took 0.19 seconds, got 13 models
#    ↳ get_models_for_make_id_year(452, 1999) took 0.19 seconds, got 15 models
#    ↳ get_models_for_make_id_year(452, 2000) took 0.28 seconds, got 17 models
#    ↳ get_models_for_make_id_year(452, 2001) took 0.21 seconds, got 16 models
#    ↳ get_models_for_make_id_year(452, 2002) took 0.18 seconds, got 16 models
#    ↳ get_models_for_make_id_year(452, 2003) took 0.20 seconds, got 21 models
#    ↳ get_models_for_make_id_year(452, 2004) took 0.18 seconds, got 18 models
#    ↳ get_models_for_make_id_year(452, 2005) took 0.20 seconds, got 18 models
#    ↳ get_models_for_make_id_year(452, 2006) took 0.18 seconds, got 22 models
#    ↳ get_models_for_make_id_year(452, 2007) took 0.28 seconds, got 17 models
#    ↳ get_models_for_make_id_year(452, 2008) took 0.19 seconds, got 20 models
#    ↳ get_models_for_make_id_year(452, 2009) took 0.19 seconds, got 16 models
#    ↳ get_models_for_make_id_year(452, 2010) took 0.19 seconds, got 19 models
#    ↳ get_models_for_make_id_year(452, 2011) took 0.19 seconds, got 19 models
#    ↳ get_models_for_make_id_year(452, 2012) took 0.19 seconds, got 27 models
#    ↳ get_models_for_make_id_year(452, 2013) took 0.27 seconds, got 28 models
#    ↳ get_models_for_make_id_year(452, 2014) took 0.30 seconds, got 37 models
#    ↳ get_models_for_make_id_year(452, 2015) took 0.22 seconds, got 37 models
#    ↳ get_models_for_make_id_year(452, 2016) took 0.19 seconds, got 28 models
#    ↳ get_models_for_make_id_year(452, 2017) took 0.22 seconds, got 29 models
#    ↳ get_models_for_make_id_year(452, 2018) took 0.21 seconds, got 31 models
#    ↳ get_models_for_make_id_year(452, 2019) took 0.29 seconds, got 29 models
#    ↳ get_models_for_make_id_year(452, 2020) took 0.19 seconds, got 26 models
#    ↳ get_models_for_make_id_year(452, 2021) took 0.22 seconds, got 27 models
#    ↳ get_models_for_make_id_year(452, 2022) took 0.23 seconds, got 29 models
#    ↳ get_models_for_make_id_year(452, 2023) took 0.20 seconds, got 27 models
#    ↳ get_models_for_make_id_year(452, 2024) took 0.19 seconds, got 26 models
#    ↳ get_models_for_make_id_year(452, 2025) took 0.20 seconds, got 27 models
#    ↳ get_models_for_make_id_year(454, 1996) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id_year(454, 1997) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id_year(454, 1998) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id_year(454, 1999) took 0.20 seconds, got 1 models
#    ↳ get_models_for_make_id_year(454, 2000) took 0.17 seconds, got 1 models
#    ↳ get_models_for_make_id_year(454, 2001) took 0.23 seconds, got 1 models
#    ↳ get_models_for_make_id_year(454, 2002) took 0.20 seconds, got 1 models
#    ↳ get_models_for_make_id_year(454, 2003) took 0.20 seconds, got 1 models
#    ↳ get_models_for_make_id_year(454, 2004) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id_year(454, 2005) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id_year(454, 2006) took 0.23 seconds, got 2 models
#    ↳ get_models_for_make_id_year(454, 2007) took 0.20 seconds, got 2 models
#    ↳ get_models_for_make_id_year(454, 2008) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id_year(454, 2009) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id_year(454, 2010) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id_year(454, 2011) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id_year(454, 2012) took 0.21 seconds, got 2 models
#    ↳ get_models_for_make_id_year(454, 2013) took 0.21 seconds, got 2 models
#    ↳ get_models_for_make_id_year(454, 2014) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id_year(454, 2015) took 0.29 seconds, got 2 models
#    ↳ get_models_for_make_id_year(454, 2016) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id_year(454, 2017) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id_year(454, 2018) took 0.35 seconds, got 2 models
#    ↳ get_models_for_make_id_year(454, 2019) took 0.20 seconds, got 2 models
#    ↳ get_models_for_make_id_year(454, 2020) took 0.19 seconds, got 4 models
#    ↳ get_models_for_make_id_year(454, 2021) took 0.20 seconds, got 4 models
#    ↳ get_models_for_make_id_year(454, 2022) took 0.18 seconds, got 4 models
#    ↳ get_models_for_make_id_year(454, 2023) took 0.18 seconds, got 4 models
#    ↳ get_models_for_make_id_year(454, 2024) took 0.19 seconds, got 4 models
#    ↳ get_models_for_make_id_year(454, 2025) took 0.21 seconds, got 2 models
#    ↳ get_models_for_make_id_year(456, 1996) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(456, 1997) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(456, 1998) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(456, 1999) took 0.23 seconds, got 0 models
#    ↳ get_models_for_make_id_year(456, 2000) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(456, 2001) took 0.23 seconds, got 0 models
#    ↳ get_models_for_make_id_year(456, 2002) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id_year(456, 2003) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id_year(456, 2004) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id_year(456, 2005) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id_year(456, 2006) took 0.39 seconds, got 2 models
#    ↳ get_models_for_make_id_year(456, 2007) took 0.20 seconds, got 2 models
#    ↳ get_models_for_make_id_year(456, 2008) took 0.68 seconds, got 3 models
#    ↳ get_models_for_make_id_year(456, 2009) took 0.76 seconds, got 4 models
#    ↳ get_models_for_make_id_year(456, 2010) took 0.17 seconds, got 4 models
#    ↳ get_models_for_make_id_year(456, 2011) took 0.26 seconds, got 4 models
#    ↳ get_models_for_make_id_year(456, 2012) took 1.00 seconds, got 6 models
#    ↳ get_models_for_make_id_year(456, 2013) took 0.17 seconds, got 7 models
#    ↳ get_models_for_make_id_year(456, 2014) took 0.19 seconds, got 7 models
#    ↳ get_models_for_make_id_year(456, 2015) took 0.19 seconds, got 6 models
#    ↳ get_models_for_make_id_year(456, 2016) took 0.18 seconds, got 5 models
#    ↳ get_models_for_make_id_year(456, 2017) took 0.19 seconds, got 4 models
#    ↳ get_models_for_make_id_year(456, 2018) took 0.18 seconds, got 4 models
#    ↳ get_models_for_make_id_year(456, 2019) took 0.19 seconds, got 4 models
#    ↳ get_models_for_make_id_year(456, 2020) took 0.17 seconds, got 3 models
#    ↳ get_models_for_make_id_year(456, 2021) took 0.19 seconds, got 3 models
#    ↳ get_models_for_make_id_year(456, 2022) took 0.18 seconds, got 3 models
#    ↳ get_models_for_make_id_year(456, 2023) took 0.18 seconds, got 3 models
#    ↳ get_models_for_make_id_year(456, 2024) took 0.21 seconds, got 3 models
#    ↳ get_models_for_make_id_year(456, 2025) took 0.21 seconds, got 2 models
#    ↳ get_models_for_make_id_year(460, 1996) took 0.23 seconds, got 9 models
#    ↳ get_models_for_make_id_year(460, 1997) took 0.23 seconds, got 9 models
#    ↳ get_models_for_make_id_year(460, 1998) took 0.23 seconds, got 6 models
#    ↳ get_models_for_make_id_year(460, 1999) took 0.22 seconds, got 7 models
#    ↳ get_models_for_make_id_year(460, 2000) took 0.19 seconds, got 8 models
#    ↳ get_models_for_make_id_year(460, 2001) took 0.29 seconds, got 7 models
#    ↳ get_models_for_make_id_year(460, 2002) took 0.21 seconds, got 8 models
#    ↳ get_models_for_make_id_year(460, 2003) took 0.18 seconds, got 7 models
#    ↳ get_models_for_make_id_year(460, 2004) took 0.19 seconds, got 7 models
#    ↳ get_models_for_make_id_year(460, 2005) took 0.20 seconds, got 8 models
#    ↳ get_models_for_make_id_year(460, 2006) took 0.19 seconds, got 8 models
#    ↳ get_models_for_make_id_year(460, 2007) took 0.29 seconds, got 7 models
#    ↳ get_models_for_make_id_year(460, 2008) took 0.19 seconds, got 6 models
#    ↳ get_models_for_make_id_year(460, 2009) took 0.20 seconds, got 6 models
#    ↳ get_models_for_make_id_year(460, 2010) took 0.23 seconds, got 6 models
#    ↳ get_models_for_make_id_year(460, 2011) took 0.19 seconds, got 7 models
#    ↳ get_models_for_make_id_year(460, 2012) took 0.20 seconds, got 6 models
#    ↳ get_models_for_make_id_year(460, 2013) took 0.19 seconds, got 7 models
#    ↳ get_models_for_make_id_year(460, 2014) took 0.32 seconds, got 7 models
#    ↳ get_models_for_make_id_year(460, 2015) took 0.20 seconds, got 7 models
#    ↳ get_models_for_make_id_year(460, 2016) took 0.22 seconds, got 7 models
#    ↳ get_models_for_make_id_year(460, 2017) took 0.22 seconds, got 8 models
#    ↳ get_models_for_make_id_year(460, 2018) took 0.22 seconds, got 8 models
#    ↳ get_models_for_make_id_year(460, 2019) took 0.23 seconds, got 7 models
#    ↳ get_models_for_make_id_year(460, 2020) took 0.22 seconds, got 6 models
#    ↳ get_models_for_make_id_year(460, 2021) took 0.18 seconds, got 5 models
#    ↳ get_models_for_make_id_year(460, 2022) took 0.18 seconds, got 5 models
#    ↳ get_models_for_make_id_year(460, 2023) took 0.19 seconds, got 5 models
#    ↳ get_models_for_make_id_year(460, 2024) took 0.20 seconds, got 5 models
#    ↳ get_models_for_make_id_year(460, 2025) took 0.21 seconds, got 6 models
#    ↳ get_models_for_make_id_year(464, 1996) took 0.22 seconds, got 3 models
#    ↳ get_models_for_make_id_year(464, 1997) took 0.20 seconds, got 3 models
#    ↳ get_models_for_make_id_year(464, 1998) took 0.20 seconds, got 3 models
#    ↳ get_models_for_make_id_year(464, 1999) took 0.21 seconds, got 2 models
#    ↳ get_models_for_make_id_year(464, 2000) took 0.19 seconds, got 3 models
#    ↳ get_models_for_make_id_year(464, 2001) took 0.18 seconds, got 3 models
#    ↳ get_models_for_make_id_year(464, 2002) took 0.19 seconds, got 3 models
#    ↳ get_models_for_make_id_year(464, 2003) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id_year(464, 2004) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id_year(464, 2005) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id_year(464, 2006) took 0.17 seconds, got 3 models
#    ↳ get_models_for_make_id_year(464, 2007) took 0.17 seconds, got 2 models
#    ↳ get_models_for_make_id_year(464, 2008) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id_year(464, 2009) took 0.25 seconds, got 3 models
#    ↳ get_models_for_make_id_year(464, 2010) took 0.19 seconds, got 3 models
#    ↳ get_models_for_make_id_year(464, 2011) took 0.20 seconds, got 3 models
#    ↳ get_models_for_make_id_year(464, 2012) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id_year(464, 2013) took 0.27 seconds, got 2 models
#    ↳ get_models_for_make_id_year(464, 2014) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id_year(464, 2015) took 0.17 seconds, got 2 models
#    ↳ get_models_for_make_id_year(464, 2016) took 0.22 seconds, got 2 models
#    ↳ get_models_for_make_id_year(464, 2017) took 0.21 seconds, got 2 models
#    ↳ get_models_for_make_id_year(464, 2018) took 0.21 seconds, got 2 models
#    ↳ get_models_for_make_id_year(464, 2019) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id_year(464, 2020) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id_year(464, 2021) took 0.20 seconds, got 1 models
#    ↳ get_models_for_make_id_year(464, 2022) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id_year(464, 2023) took 0.20 seconds, got 1 models
#    ↳ get_models_for_make_id_year(464, 2024) took 0.20 seconds, got 1 models
#    ↳ get_models_for_make_id_year(464, 2025) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id_year(465, 1996) took 0.18 seconds, got 5 models
#    ↳ get_models_for_make_id_year(465, 1997) took 0.19 seconds, got 5 models
#    ↳ get_models_for_make_id_year(465, 1998) took 0.19 seconds, got 4 models
#    ↳ get_models_for_make_id_year(465, 1999) took 0.23 seconds, got 5 models
#    ↳ get_models_for_make_id_year(465, 2000) took 0.19 seconds, got 4 models
#    ↳ get_models_for_make_id_year(465, 2001) took 0.20 seconds, got 3 models
#    ↳ get_models_for_make_id_year(465, 2002) took 0.19 seconds, got 3 models
#    ↳ get_models_for_make_id_year(465, 2003) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id_year(465, 2004) took 0.20 seconds, got 3 models
#    ↳ get_models_for_make_id_year(465, 2005) took 0.20 seconds, got 3 models
#    ↳ get_models_for_make_id_year(465, 2006) took 0.20 seconds, got 3 models
#    ↳ get_models_for_make_id_year(465, 2007) took 0.20 seconds, got 3 models
#    ↳ get_models_for_make_id_year(465, 2008) took 0.26 seconds, got 3 models
#    ↳ get_models_for_make_id_year(465, 2009) took 0.18 seconds, got 3 models
#    ↳ get_models_for_make_id_year(465, 2010) took 0.30 seconds, got 2 models
#    ↳ get_models_for_make_id_year(465, 2011) took 0.17 seconds, got 2 models
#    ↳ get_models_for_make_id_year(465, 2012) took 0.36 seconds, got 0 models
#    ↳ get_models_for_make_id_year(465, 2013) took 0.23 seconds, got 0 models
#    ↳ get_models_for_make_id_year(465, 2014) took 0.32 seconds, got 0 models
#    ↳ get_models_for_make_id_year(465, 2015) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(465, 2016) took 0.22 seconds, got 0 models
#    ↳ get_models_for_make_id_year(465, 2017) took 0.42 seconds, got 0 models
#    ↳ get_models_for_make_id_year(465, 2018) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(465, 2019) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(465, 2020) took 0.27 seconds, got 0 models
#    ↳ get_models_for_make_id_year(465, 2021) took 0.35 seconds, got 0 models
#    ↳ get_models_for_make_id_year(465, 2022) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(465, 2023) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(465, 2024) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(465, 2025) took 0.43 seconds, got 0 models
#    ↳ get_models_for_make_id_year(466, 1996) took 0.32 seconds, got 5 models
#    ↳ get_models_for_make_id_year(466, 1997) took 0.22 seconds, got 5 models
#    ↳ get_models_for_make_id_year(466, 1998) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id_year(466, 1999) took 0.21 seconds, got 1 models
#    ↳ get_models_for_make_id_year(466, 2000) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id_year(466, 2001) took 0.17 seconds, got 1 models
#    ↳ get_models_for_make_id_year(466, 2002) took 0.33 seconds, got 1 models
#    ↳ get_models_for_make_id_year(466, 2003) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id_year(466, 2004) took 0.43 seconds, got 1 models
#    ↳ get_models_for_make_id_year(466, 2005) took 0.46 seconds, got 1 models
#    ↳ get_models_for_make_id_year(466, 2006) took 0.34 seconds, got 1 models
#    ↳ get_models_for_make_id_year(466, 2007) took 0.18 seconds, got 12 models
#    ↳ get_models_for_make_id_year(466, 2008) took 0.70 seconds, got 14 models
#    ↳ get_models_for_make_id_year(466, 2009) took 0.19 seconds, got 7 models
#    ↳ get_models_for_make_id_year(466, 2010) took 0.21 seconds, got 4 models
#    ↳ get_models_for_make_id_year(466, 2011) took 0.75 seconds, got 4 models
#    ↳ get_models_for_make_id_year(466, 2012) took 0.21 seconds, got 4 models
#    ↳ get_models_for_make_id_year(466, 2013) took 0.22 seconds, got 1 models
#    ↳ get_models_for_make_id_year(466, 2014) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id_year(466, 2015) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id_year(466, 2016) took 0.55 seconds, got 1 models
#    ↳ get_models_for_make_id_year(466, 2017) took 0.21 seconds, got 1 models
#    ↳ get_models_for_make_id_year(466, 2018) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id_year(466, 2019) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id_year(466, 2020) took 0.20 seconds, got 1 models
#    ↳ get_models_for_make_id_year(466, 2021) took 0.22 seconds, got 1 models
#    ↳ get_models_for_make_id_year(466, 2022) took 0.20 seconds, got 1 models
#    ↳ get_models_for_make_id_year(466, 2023) took 0.24 seconds, got 1 models
#    ↳ get_models_for_make_id_year(466, 2024) took 0.24 seconds, got 2 models
#    ↳ get_models_for_make_id_year(466, 2025) took 0.21 seconds, got 2 models
#    ↳ get_models_for_make_id_year(467, 1996) took 0.23 seconds, got 8 models
#    ↳ get_models_for_make_id_year(467, 1997) took 0.20 seconds, got 6 models
#    ↳ get_models_for_make_id_year(467, 1998) took 0.35 seconds, got 8 models
#    ↳ get_models_for_make_id_year(467, 1999) took 0.38 seconds, got 9 models
#    ↳ get_models_for_make_id_year(467, 2000) took 0.21 seconds, got 9 models
#    ↳ get_models_for_make_id_year(467, 2001) took 0.20 seconds, got 9 models
#    ↳ get_models_for_make_id_year(467, 2002) took 0.22 seconds, got 7 models
#    ↳ get_models_for_make_id_year(467, 2003) took 0.19 seconds, got 6 models
#    ↳ get_models_for_make_id_year(467, 2004) took 0.18 seconds, got 12 models
#    ↳ get_models_for_make_id_year(467, 2005) took 0.21 seconds, got 13 models
#    ↳ get_models_for_make_id_year(467, 2006) took 0.21 seconds, got 10 models
#    ↳ get_models_for_make_id_year(467, 2007) took 0.23 seconds, got 8 models
#    ↳ get_models_for_make_id_year(467, 2008) took 0.22 seconds, got 10 models
#    ↳ get_models_for_make_id_year(467, 2009) took 0.19 seconds, got 7 models
#    ↳ get_models_for_make_id_year(467, 2010) took 0.19 seconds, got 8 models
#    ↳ get_models_for_make_id_year(467, 2011) took 0.19 seconds, got 10 models
#    ↳ get_models_for_make_id_year(467, 2012) took 0.20 seconds, got 12 models
#    ↳ get_models_for_make_id_year(467, 2013) took 0.30 seconds, got 11 models
#    ↳ get_models_for_make_id_year(467, 2014) took 0.21 seconds, got 13 models
#    ↳ get_models_for_make_id_year(467, 2015) took 0.31 seconds, got 13 models
#    ↳ get_models_for_make_id_year(467, 2016) took 0.21 seconds, got 15 models
#    ↳ get_models_for_make_id_year(467, 2017) took 0.20 seconds, got 13 models
#    ↳ get_models_for_make_id_year(467, 2018) took 0.20 seconds, got 13 models
#    ↳ get_models_for_make_id_year(467, 2019) took 0.31 seconds, got 13 models
#    ↳ get_models_for_make_id_year(467, 2020) took 0.19 seconds, got 13 models
#    ↳ get_models_for_make_id_year(467, 2021) took 0.19 seconds, got 14 models
#    ↳ get_models_for_make_id_year(467, 2022) took 0.23 seconds, got 15 models
#    ↳ get_models_for_make_id_year(467, 2023) took 0.30 seconds, got 15 models
#    ↳ get_models_for_make_id_year(467, 2024) took 0.22 seconds, got 13 models
#    ↳ get_models_for_make_id_year(467, 2025) took 0.20 seconds, got 13 models
#    ↳ get_models_for_make_id_year(468, 1996) took 0.23 seconds, got 8 models
#    ↳ get_models_for_make_id_year(468, 1997) took 0.21 seconds, got 6 models
#    ↳ get_models_for_make_id_year(468, 1998) took 0.23 seconds, got 6 models
#    ↳ get_models_for_make_id_year(468, 1999) took 0.17 seconds, got 5 models
#    ↳ get_models_for_make_id_year(468, 2000) took 0.20 seconds, got 4 models
#    ↳ get_models_for_make_id_year(468, 2001) took 0.17 seconds, got 4 models
#    ↳ get_models_for_make_id_year(468, 2002) took 0.19 seconds, got 4 models
#    ↳ get_models_for_make_id_year(468, 2003) took 0.18 seconds, got 4 models
#    ↳ get_models_for_make_id_year(468, 2004) took 0.22 seconds, got 4 models
#    ↳ get_models_for_make_id_year(468, 2005) took 0.19 seconds, got 5 models
#    ↳ get_models_for_make_id_year(468, 2006) took 0.19 seconds, got 3 models
#    ↳ get_models_for_make_id_year(468, 2007) took 0.20 seconds, got 3 models
#    ↳ get_models_for_make_id_year(468, 2008) took 0.25 seconds, got 3 models
#    ↳ get_models_for_make_id_year(468, 2009) took 0.19 seconds, got 3 models
#    ↳ get_models_for_make_id_year(468, 2010) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id_year(468, 2011) took 0.20 seconds, got 3 models
#    ↳ get_models_for_make_id_year(468, 2012) took 0.19 seconds, got 3 models
#    ↳ get_models_for_make_id_year(468, 2013) took 0.18 seconds, got 3 models
#    ↳ get_models_for_make_id_year(468, 2014) took 0.18 seconds, got 3 models
#    ↳ get_models_for_make_id_year(468, 2015) took 0.24 seconds, got 3 models
#    ↳ get_models_for_make_id_year(468, 2016) took 0.18 seconds, got 4 models
#    ↳ get_models_for_make_id_year(468, 2017) took 0.20 seconds, got 4 models
#    ↳ get_models_for_make_id_year(468, 2018) took 0.18 seconds, got 4 models
#    ↳ get_models_for_make_id_year(468, 2019) took 0.18 seconds, got 4 models
#    ↳ get_models_for_make_id_year(468, 2020) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id_year(468, 2021) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(468, 2022) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(468, 2023) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(468, 2024) took 0.22 seconds, got 0 models
#    ↳ get_models_for_make_id_year(468, 2025) took 0.21 seconds, got 0 models
#    ↳ get_models_for_make_id_year(469, 1996) took 0.18 seconds, got 5 models
#    ↳ get_models_for_make_id_year(469, 1997) took 0.20 seconds, got 5 models
#    ↳ get_models_for_make_id_year(469, 1998) took 0.25 seconds, got 6 models
#    ↳ get_models_for_make_id_year(469, 1999) took 0.17 seconds, got 6 models
#    ↳ get_models_for_make_id_year(469, 2000) took 0.20 seconds, got 6 models
#    ↳ get_models_for_make_id_year(469, 2001) took 0.18 seconds, got 6 models
#    ↳ get_models_for_make_id_year(469, 2002) took 0.19 seconds, got 5 models
#    ↳ get_models_for_make_id_year(469, 2003) took 0.23 seconds, got 6 models
#    ↳ get_models_for_make_id_year(469, 2004) took 0.22 seconds, got 4 models
#    ↳ get_models_for_make_id_year(469, 2005) took 0.22 seconds, got 4 models
#    ↳ get_models_for_make_id_year(469, 2006) took 0.18 seconds, got 4 models
#    ↳ get_models_for_make_id_year(469, 2007) took 0.20 seconds, got 4 models
#    ↳ get_models_for_make_id_year(469, 2008) took 0.19 seconds, got 4 models
#    ↳ get_models_for_make_id_year(469, 2009) took 0.18 seconds, got 4 models
#    ↳ get_models_for_make_id_year(469, 2010) took 0.23 seconds, got 3 models
#    ↳ get_models_for_make_id_year(469, 2011) took 0.20 seconds, got 3 models
#    ↳ get_models_for_make_id_year(469, 2012) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id_year(469, 2013) took 0.20 seconds, got 3 models
#    ↳ get_models_for_make_id_year(469, 2014) took 0.19 seconds, got 4 models
#    ↳ get_models_for_make_id_year(469, 2015) took 0.19 seconds, got 4 models
#    ↳ get_models_for_make_id_year(469, 2016) took 0.19 seconds, got 5 models
#    ↳ get_models_for_make_id_year(469, 2017) took 0.18 seconds, got 5 models
#    ↳ get_models_for_make_id_year(469, 2018) took 0.19 seconds, got 5 models
#    ↳ get_models_for_make_id_year(469, 2019) took 0.19 seconds, got 5 models
#    ↳ get_models_for_make_id_year(469, 2020) took 0.20 seconds, got 4 models
#    ↳ get_models_for_make_id_year(469, 2021) took 0.17 seconds, got 3 models
#    ↳ get_models_for_make_id_year(469, 2022) took 0.24 seconds, got 3 models
#    ↳ get_models_for_make_id_year(469, 2023) took 0.20 seconds, got 3 models
#    ↳ get_models_for_make_id_year(469, 2024) took 0.18 seconds, got 3 models
#    ↳ get_models_for_make_id_year(469, 2025) took 0.20 seconds, got 4 models
#    ↳ get_models_for_make_id_year(470, 1996) took 0.16 seconds, got 0 models
#    ↳ get_models_for_make_id_year(470, 1997) took 0.21 seconds, got 0 models
#    ↳ get_models_for_make_id_year(470, 1998) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(470, 1999) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(470, 2000) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(470, 2001) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(470, 2002) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(470, 2003) took 0.22 seconds, got 0 models
#    ↳ get_models_for_make_id_year(470, 2004) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(470, 2005) took 0.33 seconds, got 0 models
#    ↳ get_models_for_make_id_year(470, 2006) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(470, 2007) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(470, 2008) took 0.20 seconds, got 0 models
#    ↳ get_models_for_make_id_year(470, 2009) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(470, 2010) took 0.21 seconds, got 0 models
#    ↳ get_models_for_make_id_year(470, 2011) took 0.21 seconds, got 0 models
#    ↳ get_models_for_make_id_year(470, 2012) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(470, 2013) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id_year(470, 2014) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id_year(470, 2015) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id_year(470, 2016) took 0.23 seconds, got 1 models
#    ↳ get_models_for_make_id_year(470, 2017) took 0.17 seconds, got 1 models
#    ↳ get_models_for_make_id_year(470, 2018) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id_year(470, 2019) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id_year(470, 2020) took 0.17 seconds, got 1 models
#    ↳ get_models_for_make_id_year(470, 2021) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id_year(470, 2022) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id_year(470, 2023) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id_year(470, 2024) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id_year(470, 2025) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id_year(471, 1996) took 0.21 seconds, got 0 models
#    ↳ get_models_for_make_id_year(471, 1997) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(471, 1998) took 0.25 seconds, got 0 models
#    ↳ get_models_for_make_id_year(471, 1999) took 0.31 seconds, got 0 models
#    ↳ get_models_for_make_id_year(471, 2000) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(471, 2001) took 0.23 seconds, got 0 models
#    ↳ get_models_for_make_id_year(471, 2002) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(471, 2003) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(471, 2004) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(471, 2005) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(471, 2006) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(471, 2007) took 0.21 seconds, got 1 models
#    ↳ get_models_for_make_id_year(471, 2008) took 0.21 seconds, got 1 models
#    ↳ get_models_for_make_id_year(471, 2009) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(471, 2010) took 0.21 seconds, got 1 models
#    ↳ get_models_for_make_id_year(471, 2011) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(471, 2012) took 0.21 seconds, got 1 models
#    ↳ get_models_for_make_id_year(471, 2013) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id_year(471, 2014) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id_year(471, 2015) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id_year(471, 2016) took 0.31 seconds, got 1 models
#    ↳ get_models_for_make_id_year(471, 2017) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id_year(471, 2018) took 0.54 seconds, got 2 models
#    ↳ get_models_for_make_id_year(471, 2019) took 0.24 seconds, got 2 models
#    ↳ get_models_for_make_id_year(471, 2020) took 0.26 seconds, got 2 models
#    ↳ get_models_for_make_id_year(471, 2021) took 0.20 seconds, got 2 models
#    ↳ get_models_for_make_id_year(471, 2022) took 0.32 seconds, got 2 models
#    ↳ get_models_for_make_id_year(471, 2023) took 0.22 seconds, got 2 models
#    ↳ get_models_for_make_id_year(471, 2024) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id_year(471, 2025) took 0.21 seconds, got 2 models
#    ↳ get_models_for_make_id_year(472, 1996) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 1997) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id_year(472, 1998) took 0.23 seconds, got 1 models
#    ↳ get_models_for_make_id_year(472, 1999) took 0.21 seconds, got 1 models
#    ↳ get_models_for_make_id_year(472, 2000) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id_year(472, 2001) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 2002) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 2003) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 2004) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 2005) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 2006) took 0.20 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 2007) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 2008) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 2009) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 2010) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 2011) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 2012) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 2013) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 2014) took 0.32 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 2015) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 2016) took 0.22 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 2017) took 0.22 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 2018) took 0.21 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 2019) took 0.24 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 2020) took 0.20 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 2021) took 0.23 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 2022) took 0.26 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 2023) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 2024) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(472, 2025) took 0.23 seconds, got 0 models
#    ↳ get_models_for_make_id_year(473, 1996) took 0.31 seconds, got 8 models
#    ↳ get_models_for_make_id_year(473, 1997) took 0.19 seconds, got 5 models
#    ↳ get_models_for_make_id_year(473, 1998) took 0.19 seconds, got 3 models
#    ↳ get_models_for_make_id_year(473, 1999) took 0.20 seconds, got 4 models
#    ↳ get_models_for_make_id_year(473, 2000) took 0.18 seconds, got 4 models
#    ↳ get_models_for_make_id_year(473, 2001) took 0.19 seconds, got 4 models
#    ↳ get_models_for_make_id_year(473, 2002) took 0.26 seconds, got 4 models
#    ↳ get_models_for_make_id_year(473, 2003) took 0.17 seconds, got 3 models
#    ↳ get_models_for_make_id_year(473, 2004) took 0.20 seconds, got 5 models
#    ↳ get_models_for_make_id_year(473, 2005) took 0.22 seconds, got 4 models
#    ↳ get_models_for_make_id_year(473, 2006) took 0.20 seconds, got 5 models
#    ↳ get_models_for_make_id_year(473, 2007) took 0.19 seconds, got 5 models
#    ↳ get_models_for_make_id_year(473, 2008) took 0.19 seconds, got 5 models
#    ↳ get_models_for_make_id_year(473, 2009) took 0.19 seconds, got 5 models
#    ↳ get_models_for_make_id_year(473, 2010) took 0.18 seconds, got 5 models
#    ↳ get_models_for_make_id_year(473, 2011) took 0.18 seconds, got 6 models
#    ↳ get_models_for_make_id_year(473, 2012) took 0.21 seconds, got 6 models
#    ↳ get_models_for_make_id_year(473, 2013) took 0.20 seconds, got 5 models
#    ↳ get_models_for_make_id_year(473, 2014) took 0.22 seconds, got 5 models
#    ↳ get_models_for_make_id_year(473, 2015) took 0.20 seconds, got 5 models
#    ↳ get_models_for_make_id_year(473, 2016) took 0.17 seconds, got 5 models
#    ↳ get_models_for_make_id_year(473, 2017) took 0.20 seconds, got 5 models
#    ↳ get_models_for_make_id_year(473, 2018) took 0.19 seconds, got 5 models
#    ↳ get_models_for_make_id_year(473, 2019) took 0.34 seconds, got 5 models
#    ↳ get_models_for_make_id_year(473, 2020) took 0.17 seconds, got 5 models
#    ↳ get_models_for_make_id_year(473, 2021) took 0.18 seconds, got 5 models
#    ↳ get_models_for_make_id_year(473, 2022) took 0.20 seconds, got 4 models
#    ↳ get_models_for_make_id_year(473, 2023) took 0.24 seconds, got 3 models
#    ↳ get_models_for_make_id_year(473, 2024) took 0.27 seconds, got 3 models
#    ↳ get_models_for_make_id_year(473, 2025) took 0.18 seconds, got 3 models
# ...
#    ↳ get_models_for_make_id_year(13026, 2002) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13026, 2003) took 0.23 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13026, 2004) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13026, 2005) took 0.25 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13026, 2006) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13026, 2007) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13026, 2008) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13026, 2009) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13026, 2010) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13026, 2011) took 0.22 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13026, 2012) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13026, 2013) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13026, 2014) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13026, 2015) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13026, 2016) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13026, 2017) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13026, 2018) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13026, 2019) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13026, 2020) took 0.24 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13026, 2021) took 0.16 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13026, 2022) took 0.16 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13026, 2023) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13026, 2024) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13026, 2025) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 1996) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 1997) took 0.22 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 1998) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 1999) took 0.22 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2000) took 0.21 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2001) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2002) took 0.27 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2003) took 0.31 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2004) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2005) took 0.21 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2006) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2007) took 0.47 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2008) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2009) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2010) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2011) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2012) took 0.31 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2013) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2014) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2015) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2016) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2017) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2018) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2019) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2020) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2021) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2022) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2023) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2024) took 0.20 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13028, 2025) took 0.49 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 1996) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 1997) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 1998) took 0.75 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 1999) took 0.53 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2000) took 0.31 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2001) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2002) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2003) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2004) took 0.20 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2005) took 0.16 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2006) took 0.50 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2007) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2008) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2009) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2010) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2011) took 0.32 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2012) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2013) took 0.21 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2014) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2015) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2016) took 0.28 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2017) took 0.16 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2018) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2019) took 0.20 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2020) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2021) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2022) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2023) took 0.22 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2024) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13271, 2025) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id_year(13380, 1996) took 0.35 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 1997) took 0.40 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 1998) took 0.39 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 1999) took 0.36 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2000) took 0.29 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2001) took 0.36 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2002) took 0.45 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2003) took 0.38 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2004) took 0.44 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2005) took 0.36 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2006) took 0.40 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2007) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2008) took 0.20 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2009) took 0.21 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2010) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2011) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2012) took 0.20 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2013) took 0.22 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2014) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2015) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2016) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2017) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2018) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2019) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2020) took 0.29 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2021) took 0.16 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2022) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2023) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13380, 2024) took 0.16 seconds, got 1 models
#    ↳ get_models_for_make_id_year(13380, 2025) took 0.20 seconds, got 1 models
#    ↳ get_models_for_make_id_year(13391, 1996) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 1997) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 1998) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 1999) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2000) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2001) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2002) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2003) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2004) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2005) took 0.26 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2006) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2007) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2008) took 0.20 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2009) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2010) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2011) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2012) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2013) took 0.37 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2014) took 0.31 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2015) took 0.30 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2016) took 0.16 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2017) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2018) took 0.16 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2019) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2020) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2021) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2022) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2023) took 0.27 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2024) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13391, 2025) took 0.18 seconds, got 4 models
#    ↳ get_models_for_make_id_year(13585, 1996) took 0.21 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 1997) took 0.25 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 1998) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 1999) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2000) took 0.16 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2001) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2002) took 0.21 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2003) took 0.16 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2004) took 0.26 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2005) took 0.16 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2006) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2007) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2008) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2009) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2010) took 0.22 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2011) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2012) took 0.22 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2013) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2014) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2015) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2016) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2017) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2018) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2019) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2020) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2021) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2022) took 0.16 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2023) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2024) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13585, 2025) took 0.18 seconds, got 13 models
#    ↳ get_models_for_make_id_year(13647, 1996) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 1997) took 0.22 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 1998) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 1999) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2000) took 0.22 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2001) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2002) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2003) took 0.29 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2004) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2005) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2006) took 0.21 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2007) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2008) took 0.16 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2009) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2010) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2011) took 0.16 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2012) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2013) took 0.17 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2014) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2015) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2016) took 0.25 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2017) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2018) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2019) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2020) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2021) took 0.19 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2022) took 0.22 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2023) took 0.18 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2024) took 0.16 seconds, got 0 models
#    ↳ get_models_for_make_id_year(13647, 2025) took 0.18 seconds, got 0 models
# ✅ Saved car_makes_models_us.csv with 11241 rows
# ⏱ Total process time: 1193.66 seconds

# %%
#CarQuery API Call


import requests
import json
import time

headers = {
    "Accept": "application/json",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36"
}

all_makes = set()

for year in range(1941, 2023):
    url = f"https://www.carqueryapi.com/api/0.3/?cmd=getMakes&year={year}&sold_in_us=1"
    res = requests.get(url, headers=headers)
    
    if not res.text.strip():
        print(f"No data for year {year}")
        continue
    
    try:
        data = json.loads(res.text)
    except Exception as e:
        print(f"Failed for year {year}: {e}")
        print("Raw response:", res.text[:200])
        continue

    for make in data.get("Makes", []):
        all_makes.add(make["make_display"])
    
    time.sleep(0.2)  # be polite, avoid rate-limit

print("✅ Total unique makes:", len(all_makes))
print(sorted(all_makes))
# Out:
# ✅ Total unique makes: 0
# []
