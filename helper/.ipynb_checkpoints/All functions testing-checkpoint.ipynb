# %%
import os
import pandas as pd
import json

# go up one level from current working dir (same pattern as your pricing script)
# BASE_DIR = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))
# DATA_DIR = os.path.join(BASE_DIR, "data")

# CSV_FILE = os.path.join(DATA_DIR, "cars.csv")
# JSON_FILE = os.path.join(DATA_DIR, "cars.json")

CSV_FILE = "cars.csv"
JSON_FILE = "cars.json"

print("Looking for CSV at:", CSV_FILE)

# If your cars.csv is tab-separated (which matches the file you pasted):
df = pd.read_csv(CSV_FILE)

# If instead it’s space-separated, use this line instead:
# df = pd.read_csv(CSV_FILE, delim_whitespace=True)


# Normalize headers
df.columns = df.columns.str.strip().str.lower()
print("Columns found:", df.columns.tolist())  # should show ['make','model','car_type','upcharge_percentage']

print("Columns found:", df.columns.tolist())  # debug

cars = {}

# Iterate rows safely
for _, row in df.iterrows():
    make = str(row["make"]).strip()
    model = str(row["model"]).strip()
    car_type = str(row["car_type"]).strip()
    upcharge = float(row["upcharge_percentage"])

    if make not in cars:
        cars[make] = {"label": make, "models": {}}

    cars[make]["models"][model] = {
        "label": model,
        "car_type": car_type,
        "upcharge_percentage": upcharge
    }

# Save JSON
with open(JSON_FILE, "w", encoding="utf-8") as f:
    json.dump(cars, f, indent=2, ensure_ascii=False)

print(f"✅ cars.json created successfully at {JSON_FILE}")

# Show first 2 makes as a sample
sample = {k: cars[k] for k in list(cars.keys())[:2]}
print(json.dumps(sample, indent=2, ensure_ascii=False))
# Out:
# Looking for CSV at: cars.csv
# Columns found: ['make', 'model', 'car_type', 'upcharge_percentage']
# Columns found: ['make', 'model', 'car_type', 'upcharge_percentage']
# ✅ cars.json created successfully at cars.json
# {
#   "Skoda": {
#     "label": "Skoda",
#     "models": {
#       "Octavia": {
#         "label": "Octavia",
#         "car_type": "Standard",
#         "upcharge_percentage": 0.0
#       }
#     }
#   },
#   "Acura": {
#     "label": "Acura",
#     "models": {
#       "MDX": {
#         "label": "MDX",
#         "car_type": "Standard",
#         "upcharge_percentage": 0.0
#       },
#       "RDX": {
#         "label": "RDX",
#         "car_type": "Standard",
#         "upcharge_percentage": 0.0
#       }
#     }
#   }
# }

# %%
import requests
import pandas as pd

def get_car_makes():
    """
    Fetch only car makes that produce passenger cars.
    Returns a list of dicts: [{'id': ..., 'name': ...}, ...]
    """
    url = "https://vpic.nhtsa.dot.gov/api/vehicles/GetMakesForVehicleType/car?format=json"
    res = requests.get(url)
    res.raise_for_status()
    data = res.json()
    return [{"id": m["MakeId"], "name": m["MakeName"]} for m in data["Results"]]

def get_models_for_make_id(make_id: int):
    """
    Fetch models for a specific make using Make_ID.
    Returns a list of model names.
    """
    url = f"https://vpic.nhtsa.dot.gov/api/vehicles/GetModelsForMakeId/{make_id}?format=json"
    res = requests.get(url)
    res.raise_for_status()
    data = res.json()
    return [m["Model_Name"] for m in data["Results"]]

# Build flat list of make+model
all_rows = []
makes = get_car_makes()

for make in makes:
    try:
        models = get_models_for_make_id(make["id"])
        for model in models:
            all_rows.append({
                "make": make["name"].strip(),
                "model": model.strip()
            })
    except Exception as e:
        print(f"Skipping {make['name']} (ID {make['id']}): {e}")

# Create DataFrame and drop duplicates
df = pd.DataFrame(all_rows).drop_duplicates().reset_index(drop=True)

df = df.drop_duplicates().reset_index(drop=True)

df.to_csv("car_makes_models_from_api.csv", index=False)
print("✅ Saved car_makes_models_from_api.csv with", len(df), "rows")
# Preview first 20 rows
# df.head(20)
# Out:
# ✅ Saved car_makes_models_from_api.csv with 3130 rows

# %%
import requests
import pandas as pd
import time

def get_car_makes():
    """
    Fetch only car makes that produce passenger cars.
    Returns a list of dicts: [{'id': ..., 'name': ...}, ...]
    """
    start = time.time()
    url = "https://vpic.nhtsa.dot.gov/api/vehicles/GetMakesForVehicleType/car?format=json"
    res = requests.get(url)
    res.raise_for_status()
    data = res.json()
    makes = [{"id": m["MakeId"], "name": m["MakeName"]} for m in data["Results"]]
    end = time.time()
    print(f"⏱ get_car_makes() took {end - start:.2f} seconds")
    return makes

def get_models_for_make_id(make_id: int):
    """
    Fetch models for a specific make using Make_ID.
    Returns a list of model names.
    """
    start = time.time()
    url = f"https://vpic.nhtsa.dot.gov/api/vehicles/GetModelsForMakeId/{make_id}?format=json"
    res = requests.get(url)
    res.raise_for_status()
    data = res.json()
    models = [m["Model_Name"] for m in data["Results"]]
    end = time.time()
    print(f"   ↳ get_models_for_make_id({make_id}) took {end - start:.2f} seconds, got {len(models)} models")
    return models

# Measure whole process
overall_start = time.time()

# Build flat list of make+model
all_rows = []
makes = get_car_makes()

for make in makes:
    try:
        models = get_models_for_make_id(make["id"])
        for model in models:
            all_rows.append({
                "make": make["name"].strip(),
                "model": model.strip()
            })
    except Exception as e:
        print(f"Skipping {make['name']} (ID {make['id']}): {e}")

# Create DataFrame and drop duplicates
df = pd.DataFrame(all_rows).drop_duplicates().reset_index(drop=True)

df.to_csv("car_makes_models_from_api.csv", index=False)

overall_end = time.time()

print("✅ Saved car_makes_models_from_api.csv with", len(df), "rows")
print(f"⏱ Total process time: {overall_end - overall_start:.2f} seconds")
# Out:
# ⏱ get_car_makes() took 0.46 seconds
#    ↳ get_models_for_make_id(440) took 0.17 seconds, got 18 models
#    ↳ get_models_for_make_id(441) took 0.18 seconds, got 7 models
#    ↳ get_models_for_make_id(442) took 0.19 seconds, got 17 models
#    ↳ get_models_for_make_id(443) took 0.18 seconds, got 14 models
#    ↳ get_models_for_make_id(445) took 0.19 seconds, got 15 models
#    ↳ get_models_for_make_id(448) took 0.21 seconds, got 56 models
#    ↳ get_models_for_make_id(449) took 0.19 seconds, got 60 models
#    ↳ get_models_for_make_id(452) took 0.19 seconds, got 258 models
#    ↳ get_models_for_make_id(454) took 0.20 seconds, got 6 models
#    ↳ get_models_for_make_id(456) took 0.20 seconds, got 8 models
#    ↳ get_models_for_make_id(460) took 0.24 seconds, got 149 models
#    ↳ get_models_for_make_id(464) took 0.17 seconds, got 17 models
#    ↳ get_models_for_make_id(465) took 0.17 seconds, got 17 models
#    ↳ get_models_for_make_id(466) took 0.21 seconds, got 19 models
#    ↳ get_models_for_make_id(467) took 0.18 seconds, got 124 models
#    ↳ get_models_for_make_id(468) took 0.17 seconds, got 27 models
#    ↳ get_models_for_make_id(469) took 0.21 seconds, got 37 models
#    ↳ get_models_for_make_id(470) took 0.17 seconds, got 3 models
#    ↳ get_models_for_make_id(471) took 0.19 seconds, got 6 models
#    ↳ get_models_for_make_id(472) took 0.18 seconds, got 61 models
#    ↳ get_models_for_make_id(473) took 0.16 seconds, got 28 models
#    ↳ get_models_for_make_id(474) took 0.18 seconds, got 541 models
#    ↳ get_models_for_make_id(475) took 0.19 seconds, got 17 models
#    ↳ get_models_for_make_id(476) took 0.18 seconds, got 51 models
#    ↳ get_models_for_make_id(477) took 0.18 seconds, got 38 models
#    ↳ get_models_for_make_id(478) took 0.18 seconds, got 44 models
#    ↳ get_models_for_make_id(480) took 0.17 seconds, got 33 models
#    ↳ get_models_for_make_id(481) took 0.18 seconds, got 32 models
#    ↳ get_models_for_make_id(482) took 0.20 seconds, got 40 models
#    ↳ get_models_for_make_id(485) took 0.21 seconds, got 64 models
#    ↳ get_models_for_make_id(492) took 0.19 seconds, got 11 models
#    ↳ get_models_for_make_id(493) took 0.18 seconds, got 9 models
#    ↳ get_models_for_make_id(497) took 0.18 seconds, got 3 models
#    ↳ get_models_for_make_id(498) took 0.18 seconds, got 37 models
#    ↳ get_models_for_make_id(499) took 0.19 seconds, got 24 models
#    ↳ get_models_for_make_id(502) took 0.20 seconds, got 9 models
#    ↳ get_models_for_make_id(504) took 0.19 seconds, got 4 models
#    ↳ get_models_for_make_id(509) took 0.21 seconds, got 393 models
#    ↳ get_models_for_make_id(515) took 0.22 seconds, got 17 models
#    ↳ get_models_for_make_id(523) took 0.19 seconds, got 24 models
#    ↳ get_models_for_make_id(533) took 0.21 seconds, got 2 models
#    ↳ get_models_for_make_id(536) took 0.18 seconds, got 37 models
#    ↳ get_models_for_make_id(542) took 0.23 seconds, got 46 models
#    ↳ get_models_for_make_id(565) took 0.19 seconds, got 34 models
#    ↳ get_models_for_make_id(572) took 0.20 seconds, got 7 models
#    ↳ get_models_for_make_id(582) took 0.18 seconds, got 55 models
#    ↳ get_models_for_make_id(583) took 0.16 seconds, got 12 models
#    ↳ get_models_for_make_id(584) took 0.16 seconds, got 15 models
#    ↳ get_models_for_make_id(603) took 0.18 seconds, got 83 models
#    ↳ get_models_for_make_id(606) took 0.17 seconds, got 1 models
#    ↳ get_models_for_make_id(629) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id(771) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id(847) took 0.17 seconds, got 3 models
#    ↳ get_models_for_make_id(972) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id(986) took 0.20 seconds, got 9 models
#    ↳ get_models_for_make_id(992) took 0.23 seconds, got 1 models
#    ↳ get_models_for_make_id(1056) took 0.21 seconds, got 24 models
#    ↳ get_models_for_make_id(1077) took 0.23 seconds, got 6 models
#    ↳ get_models_for_make_id(1124) took 0.29 seconds, got 4 models
#    ↳ get_models_for_make_id(1142) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id(1146) took 0.18 seconds, got 6 models
#    ↳ get_models_for_make_id(1151) took 0.22 seconds, got 5 models
#    ↳ get_models_for_make_id(1288) took 0.16 seconds, got 6 models
#    ↳ get_models_for_make_id(1292) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(1393) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id(1498) took 0.18 seconds, got 4 models
#    ↳ get_models_for_make_id(1683) took 0.21 seconds, got 1 models
#    ↳ get_models_for_make_id(1755) took 0.21 seconds, got 2 models
#    ↳ get_models_for_make_id(1777) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(1869) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(1896) took 0.17 seconds, got 6 models
#    ↳ get_models_for_make_id(1991) took 0.32 seconds, got 32 models
#    ↳ get_models_for_make_id(2018) took 0.18 seconds, got 17 models
#    ↳ get_models_for_make_id(2049) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(2131) took 0.17 seconds, got 1 models
#    ↳ get_models_for_make_id(2236) took 0.27 seconds, got 19 models
#    ↳ get_models_for_make_id(2376) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(2408) took 0.18 seconds, got 7 models
#    ↳ get_models_for_make_id(2409) took 0.17 seconds, got 20 models
#    ↳ get_models_for_make_id(2665) took 0.20 seconds, got 1 models
#    ↳ get_models_for_make_id(2745) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(3176) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id(3440) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(3540) took 0.27 seconds, got 2 models
#    ↳ get_models_for_make_id(3583) took 0.31 seconds, got 17 models
#    ↳ get_models_for_make_id(3706) took 0.23 seconds, got 2 models
#    ↳ get_models_for_make_id(3766) took 0.23 seconds, got 3 models
#    ↳ get_models_for_make_id(4162) took 0.17 seconds, got 21 models
#    ↳ get_models_for_make_id(4220) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(4355) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(4410) took 0.17 seconds, got 4 models
#    ↳ get_models_for_make_id(4451) took 0.19 seconds, got 8 models
#    ↳ get_models_for_make_id(4596) took 0.22 seconds, got 1 models
#    ↳ get_models_for_make_id(4634) took 0.17 seconds, got 6 models
#    ↳ get_models_for_make_id(4644) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(4764) took 0.17 seconds, got 2 models
#    ↳ get_models_for_make_id(4767) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id(4859) took 0.23 seconds, got 1 models
#    ↳ get_models_for_make_id(5015) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id(5042) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id(5083) took 0.21 seconds, got 6 models
#    ↳ get_models_for_make_id(5122) took 0.17 seconds, got 7 models
#    ↳ get_models_for_make_id(5208) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(5367) took 0.17 seconds, got 16 models
#    ↳ get_models_for_make_id(5381) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(5464) took 0.26 seconds, got 1 models
#    ↳ get_models_for_make_id(5468) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id(5552) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id(5553) took 0.19 seconds, got 4 models
#    ↳ get_models_for_make_id(5554) took 0.18 seconds, got 4 models
#    ↳ get_models_for_make_id(5555) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id(5557) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id(5657) took 0.17 seconds, got 4 models
#    ↳ get_models_for_make_id(5661) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(5760) took 0.27 seconds, got 2 models
#    ↳ get_models_for_make_id(5767) took 0.40 seconds, got 1 models
#    ↳ get_models_for_make_id(5848) took 0.36 seconds, got 1 models
#    ↳ get_models_for_make_id(5938) took 0.39 seconds, got 1 models
#    ↳ get_models_for_make_id(6018) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(6069) took 0.30 seconds, got 3 models
#    ↳ get_models_for_make_id(6263) took 0.36 seconds, got 2 models
#    ↳ get_models_for_make_id(6264) took 0.45 seconds, got 1 models
#    ↳ get_models_for_make_id(6265) took 0.38 seconds, got 2 models
#    ↳ get_models_for_make_id(6313) took 0.44 seconds, got 1 models
#    ↳ get_models_for_make_id(6364) took 0.35 seconds, got 1 models
#    ↳ get_models_for_make_id(6408) took 0.39 seconds, got 1 models
#    ↳ get_models_for_make_id(6473) took 0.38 seconds, got 3 models
#    ↳ get_models_for_make_id(6663) took 0.20 seconds, got 2 models
#    ↳ get_models_for_make_id(6759) took 0.50 seconds, got 1 models
#    ↳ get_models_for_make_id(6792) took 0.19 seconds, got 3 models
#    ↳ get_models_for_make_id(6880) took 0.17 seconds, got 7 models
#    ↳ get_models_for_make_id(6986) took 0.19 seconds, got 4 models
#    ↳ get_models_for_make_id(7099) took 0.17 seconds, got 2 models
#    ↳ get_models_for_make_id(7207) took 0.17 seconds, got 2 models
#    ↳ get_models_for_make_id(7225) took 0.21 seconds, got 5 models
#    ↳ get_models_for_make_id(7425) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(7477) took 0.20 seconds, got 5 models
#    ↳ get_models_for_make_id(7765) took 0.17 seconds, got 5 models
#    ↳ get_models_for_make_id(7836) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(8395) took 0.17 seconds, got 1 models
#    ↳ get_models_for_make_id(8549) took 0.17 seconds, got 2 models
#    ↳ get_models_for_make_id(8605) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id(8785) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id(9250) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(9326) took 0.17 seconds, got 1 models
#    ↳ get_models_for_make_id(9364) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(9376) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(9401) took 0.18 seconds, got 3 models
#    ↳ get_models_for_make_id(9448) took 0.17 seconds, got 1 models
#    ↳ get_models_for_make_id(9458) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(9533) took 0.21 seconds, got 1 models
#    ↳ get_models_for_make_id(9572) took 0.18 seconds, got 3 models
#    ↳ get_models_for_make_id(9720) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(9759) took 0.17 seconds, got 16 models
#    ↳ get_models_for_make_id(10029) took 0.17 seconds, got 6 models
#    ↳ get_models_for_make_id(10030) took 0.19 seconds, got 2 models
#    ↳ get_models_for_make_id(10031) took 0.17 seconds, got 2 models
#    ↳ get_models_for_make_id(10047) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(10224) took 0.16 seconds, got 4 models
#    ↳ get_models_for_make_id(10256) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(10393) took 0.18 seconds, got 6 models
#    ↳ get_models_for_make_id(10623) took 0.18 seconds, got 3 models
#    ↳ get_models_for_make_id(10647) took 0.20 seconds, got 1 models
#    ↳ get_models_for_make_id(10919) took 0.23 seconds, got 2 models
#    ↳ get_models_for_make_id(11076) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(11346) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(11792) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(11832) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id(11856) took 0.19 seconds, got 3 models
#    ↳ get_models_for_make_id(11921) took 0.15 seconds, got 1 models
#    ↳ get_models_for_make_id(11938) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id(12074) took 0.16 seconds, got 2 models
#    ↳ get_models_for_make_id(12400) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(12550) took 0.16 seconds, got 4 models
#    ↳ get_models_for_make_id(12706) took 0.20 seconds, got 1 models
#    ↳ get_models_for_make_id(12771) took 0.18 seconds, got 3 models
#    ↳ get_models_for_make_id(12783) took 0.17 seconds, got 2 models
#    ↳ get_models_for_make_id(12894) took 0.17 seconds, got 3 models
#    ↳ get_models_for_make_id(12948) took 0.17 seconds, got 1 models
#    ↳ get_models_for_make_id(12980) took 0.22 seconds, got 1 models
#    ↳ get_models_for_make_id(12991) took 0.18 seconds, got 2 models
#    ↳ get_models_for_make_id(13018) took 0.17 seconds, got 2 models
#    ↳ get_models_for_make_id(13022) took 0.16 seconds, got 1 models
#    ↳ get_models_for_make_id(13024) took 0.21 seconds, got 1 models
#    ↳ get_models_for_make_id(13025) took 0.20 seconds, got 2 models
#    ↳ get_models_for_make_id(13026) took 0.19 seconds, got 1 models
#    ↳ get_models_for_make_id(13028) took 0.21 seconds, got 1 models
#    ↳ get_models_for_make_id(13271) took 0.17 seconds, got 1 models
#    ↳ get_models_for_make_id(13380) took 0.18 seconds, got 1 models
#    ↳ get_models_for_make_id(13391) took 0.20 seconds, got 4 models
#    ↳ get_models_for_make_id(13585) took 0.17 seconds, got 13 models
#    ↳ get_models_for_make_id(13647) took 0.21 seconds, got 5 models
# ✅ Saved car_makes_models_from_api.csv with 3130 rows
# ⏱ Total process time: 39.60 seconds

# %%
# #Don't use this one it takes significant time


# import requests
# import pandas as pd
# import time

# def get_car_makes():
#     """
#     Fetch only car makes that produce passenger cars in the US.
#     Returns a list of dicts: [{'id': ..., 'name': ...}, ...]
#     """
#     start = time.time()
#     url = "https://vpic.nhtsa.dot.gov/api/vehicles/GetMakesForVehicleType/car?format=json"
#     res = requests.get(url)
#     res.raise_for_status()
#     data = res.json()
#     makes = [{"id": m["MakeId"], "name": m["MakeName"]} for m in data["Results"]]
#     end = time.time()
#     print(f"⏱ get_car_makes() took {end - start:.2f} seconds")
#     return makes

# def get_models_for_make_id_year(make_id: int, year: int):
#     """
#     Fetch car models for a specific make_id and year.
#     Only returns US passenger cars certified/sold in that year.
#     """
#     start = time.time()
#     url = f"https://vpic.nhtsa.dot.gov/api/vehicles/GetModelsForMakeIdYear/makeId/{make_id}/modelyear/{year}/vehicleType/car?format=json"
#     res = requests.get(url)
#     res.raise_for_status()
#     data = res.json()
#     models = [m["Model_Name"] for m in data["Results"]]
#     end = time.time()
#     print(f"   ↳ get_models_for_make_id_year({make_id}, {year}) took {end - start:.2f} seconds, got {len(models)} models")
#     return models

# # Measure whole process
# overall_start = time.time()

# # Choose year(s) you care about (e.g., last 5 years to cover current sales)
# years = range(1996, 2026)

# all_rows = []
# makes = get_car_makes()

# for make in makes:
#     try:
#         for year in years:
#             models = get_models_for_make_id_year(make["id"], year)
#             for model in models:
#                 all_rows.append({
#                     "make": make["name"].strip(),
#                     "model": model.strip(),
#                     "year": year
#                 })
#     except Exception as e:
#         print(f"Skipping {make['name']} (ID {make['id']}): {e}")

# # Create DataFrame and drop duplicates
# df = pd.DataFrame(all_rows).drop_duplicates().reset_index(drop=True)

# df.to_csv("car_makes_models_us.csv", index=False)

# overall_end = time.time()

# print("✅ Saved car_makes_models_us.csv with", len(df), "rows")
# print(f"⏱ Total process time: {overall_end - overall_start:.2f} seconds")

# %%
#CarQuery API Call


import requests
import json
import time

headers = {
    "Accept": "application/json",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36"
}

all_makes = set()

for year in range(1941, 2023):
    url = f"https://www.carqueryapi.com/api/0.3/?cmd=getMakes&year={year}&sold_in_us=1"
    res = requests.get(url, headers=headers)
    
    if not res.text.strip():
        print(f"No data for year {year}")
        continue
    
    try:
        data = json.loads(res.text)
    except Exception as e:
        print(f"Failed for year {year}: {e}")
        print("Raw response:", res.text[:200])
        continue

    for make in data.get("Makes", []):
        all_makes.add(make["make_display"])
    
    time.sleep(0.2)  # be polite, avoid rate-limit

print("✅ Total unique makes:", len(all_makes))
print(sorted(all_makes))
# Out:
# ✅ Total unique makes: 0
# []

# %%
#Google Distance Matrix Function


import requests


def get_distance(origin, destination):
    url = "https://maps.googleapis.com/maps/api/distancematrix/json"
    params = {
        "origins": origin,
        "destinations": destination,
        "key": API_KEY,
        "units": "imperial"  # miles instead of km
    }
    response = requests.get(url, params=params)
    data = response.json()
    
    if data["status"] != "OK":
        raise Exception(f"Error from API: {data}")
    
    element = data["rows"][0]["elements"][0]
    if element["status"] != "OK":
        raise Exception(f"Error in element: {element}")
    
    distance_text = element["distance"]["text"]  # e.g. "123 mi"
    distance_value = element["distance"]["value"]  # in meters
    return distance_text, distance_value

# %%
origin = "1520 Milner Crescent, Birmingham, AL 35205"
destination = "U.S. Space & Rocket Center, 1 Tranquility Base, Huntsville, AL 35805"
API_KEY = "your_api_key"  # paste your new key here
get_distance(origin, destination)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[29], line 4
#       2 destination = "U.S. Space & Rocket Center, 1 Tranquility Base, Huntsville, AL 35805"
#       3 API_KEY = "your_api_key"  # paste your new key here
# ----> 4 get_distance(origin, destination)
#
# Cell In[28], line 19, in get_distance(origin, destination)
#      16 data = response.json()
#      18 if data["status"] != "OK":
# ---> 19     raise Exception(f"Error from API: {data}")
#      21 element = data["rows"][0]["elements"][0]
#      22 if element["status"] != "OK":
#
# Exception: Error from API: {'destination_addresses': [], 'error_message': 'The provided API key is invalid. ', 'origin_addresses': [], 'rows': [], 'status': 'REQUEST_DENIED'}

# %%
def get_distance2(origin, destination):
    url = "https://maps.googleapis.com/maps/api/distancematrix/json"
    params = {
        "origins": origin,
        "destinations": destination,
        "key": API_KEY,
        "units": "imperial"  # miles
    }
    response = requests.get(url, params=params)
    data = response.json()

    if data["status"] != "OK":
        raise Exception(f"Error from API: {data}")

    element = data["rows"][0]["elements"][0]
    if element["status"] != "OK":
        raise Exception(f"Error in element: {element}")

    # Distance
    distance_value = element["distance"]["value"]  # meters
    miles = distance_value / 1609.34

    # Round consistently to 1 decimal place
    miles_rounded = round(miles, 1)                # numeric
    distance_text = f"{miles_rounded:.1f} mi"      # string with 1 decimal

    # Normalized addresses (Google's best guess)
    resolved_origin = data.get("origin_addresses", [""])[0]
    resolved_destination = data.get("destination_addresses", [""])[0]

    return {
        "miles": miles_rounded,                # e.g. 21.2
        "distance_text": distance_text,        # e.g. "21.2 mi"
        "resolved_origin": resolved_origin,
        "resolved_destination": resolved_destination
    }

# %%
origin = "Hurst Towing, Fultondale"
destination = "Costco Hoover"

get_distance2(origin, destination)
# Out:
# {'miles': 21.2,
#  'distance_text': '21.2 mi',
#  'resolved_origin': '1620 Carson Rd N, Birmingham, AL 35217, USA',
#  'resolved_destination': '3650 Galleria Cir, Hoover, AL 35244, USA'}
